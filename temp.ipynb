# %%
# !ls 1*.ipynb
# Out:
# 1.data.ipynb				1.data.lowres.ipynb
# 1.data.latent.ipynb			1.data.lowres.sample.ipynb
# 1.data.latent.sample.ipynb		1.data.lowres.train.ipynb
# 1.data.latent.train.ipynb		1.data.lowres.train.v2.ipynb
# 1.data.latent.train.middle.check.ipynb

# %%
# 1.data.ipynb  数据

# file_dicts.json

# %%
# 1.data.latent.ipynb 

# read file_dicts.json 


# update file_dicts.json 

'''
image:
source_image : 
image_latent : 
source_image_latent : 



'''

# %%
# 1.data.latent.train.ipynb 
# folder : latent/
# training

# %%
# hospital A ,B ,C, D = > file_dicts.json  => latent/ folder 
# 
# = > 1.data.latent.train.ipynb

# %%
# 1.data.latent.train.ipynb  => model.pt  , latent 
# 1.data.latent.train_v2.ipynb
